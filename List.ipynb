# %%
###   Find the List Any Data By Indexing   ###
x=["Apple","Cherry","Guava","Papaya","Litchi","Mango"]
x[1]
x[1:]
x[-1]
x[-7:5]
x[0:]
# Out:
# ['Apple', 'Cherry', 'Guava', 'Papaya', 'Litchi', 'Mango']

# %% [markdown]
# ##  Adding  ##

# %%
## Add New In List ##
x=["Apple","Cherry","Guava","Papaya","Litchi","Mango"]
x.append("Ram")
x
# Out:
# ['Apple', 'Cherry', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']

# %%
x.insert(2,"Orange")
x
# Out:
# ['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']

# %%
##  For Adding Two List   ###
x=["Apple","Cherry","Guava"]
y=["Papaya","Litchi","Mango"]
x.extend(y)
x
# Out:
# ['Apple', 'Cherry', 'Guava', 'Papaya', 'Litchi', 'Mango']

# %% [markdown]
#  ###   Remove Methods #

# %%
##  Remove By Indexing  ##
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.pop()
x
# Out:
# ['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango']

# %%
['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.pop(0)
x
# Out:
# ['Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango']

# %%
##  Delete By Name  ##
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.remove("Ram")
x
# Out:
# ['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango']

# %%
##   Clear All List  ##
['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.clear()
x
# Out:
# []

# %% [markdown]
# ##  Update Methods ##

# %%
##  Update By Indexing  ##
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x[6]="Water Melon"
x
# Out:
# ['Apple',
#  'Cherry',
#  'Orange',
#  'Guava',
#  'Papaya',
#  'Litchi',
#  'Water Melon',
#  'Ram']

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x[1:5]=["Ram","Sita","Hanuman"]
x
# Out:
# ['Apple', 'Ram', 'Sita', 'Hanuman', 'Litchi', 'Mango', 'Ram']

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x[1:3]=["Guava","Cherry","Orange"]
x
# Out:
# ['Apple',
#  'Guava',
#  'Cherry',
#  'Orange',
#  'Guava',
#  'Papaya',
#  'Litchi',
#  'Mango',
#  'Ram']

# %% [markdown]
# ##  Searching  ##

# %%
##  Search index of any word  ##
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.index("Cherry")
# Out:
# 1

# %%
##  Serch the word how many time repeat  ##
x=['Apple',
 'Guava',
 'Cherry',
 'Orange',
 'Guava',
 'Papaya',
 'Litchi',
 'Mango',
 'Ram']
x.count("Guava")
# Out:
# 2

# %%
##  Searching By In Operator   ##
x=['Apple',
 'Guava',
 'Cherry',
 'Orange',
 'Guava',
 'Papaya',
 'Litchi',
 'Mango',
 'Ram']
"Ram" in x
# Out:
# True

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
"Sita" in x
# Out:
# False

# %% [markdown]
# ##  Ordering and Rearranging

# %%
##   
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.sort()
x
# Out:
# ['Apple', 'Cherry', 'Guava', 'Litchi', 'Mango', 'Orange', 'Papaya', 'Ram']

# %%
x.reverse()
x
# Out:
# ['Ram', 'Papaya', 'Orange', 'Mango', 'Litchi', 'Guava', 'Cherry', 'Apple']

# %%
x.sort(key=None,reverse=False)
x
# Out:
# ['Apple', 'Cherry', 'Guava', 'Litchi', 'Mango', 'Orange', 'Papaya', 'Ram']

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.sort(key=None,reverse=False)
x
# Out:
# ['Apple', 'Cherry', 'Guava', 'Litchi', 'Mango', 'Orange', 'Papaya', 'Ram']

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
x.sort(key=None,reverse=True)
x
# Out:
# ['Ram', 'Papaya', 'Orange', 'Mango', 'Litchi', 'Guava', 'Cherry', 'Apple']

# %% [markdown]
# ## copy Method

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
y=x.copy()
y
# Out:
# ['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']

# %% [markdown]
#  ##  Other Methods

# %%
x=['Apple', 'Cherry', 'Orange', 'Guava', 'Papaya', 'Litchi', 'Mango', 'Ram']
len(x)
# Out:
# 8

# %%
x=[1,2,3,4,5,6,4,3,2,1,5,6,7,96,6,5,8,8,6,6,5,5,6,7,7,66,6,55,5,5,64,646,4,5,75,474,7,47,47,47,45,74]
max(x)
# Out:
# 646

# %%
x=[1,2,3,4,5,6,4,3,2,1,5,6,7,96,6,5,8,8,6,6,5,5,6,7,7,66,6,55,5,5,64,646,4,5,75,474,7,47,47,47,45,74]
min(x)
# Out:
# 1

# %%
x=[1,2,3,4,5,6,4,3,2,1,5,6,7,96,6,5,8,8,6,6,5,5,6,7,7,66,6,55,5,5,64,646,4,5,75,474,7,47,47,47,45,74]
sum(x)
# Out:
# 1886
