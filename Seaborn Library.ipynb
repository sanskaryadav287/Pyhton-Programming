# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("tip.csv")

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
  df1.shape
# Out:
# (244, 7)

# %%
df1.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df1.drop(["size"], axis=1,inplace=True)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time
# 0         16.99  1.01  Female     No   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
pd.isnull(df1)
# Out:
#      total_bill    tip    sex  smoker    day   time
# 0         False  False  False   False  False  False
# 1         False  False  False   False  False  False
# 2         False  False  False   False  False  False
# 3         False  False  False   False  False  False
# 4         False  False  False   False  False  False
# ..          ...    ...    ...     ...    ...    ...
# 239       False  False  False   False  False  False
# 240       False  False  False   False  False  False
# 241       False  False  False   False  False  False
# 242       False  False  False   False  False  False
# 243       False  False  False   False  False  False
#
# [244 rows x 6 columns]

# %%
df1.shape
# Out:
# (244, 6)

# %%
df1.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time
# 0         16.99  1.01  Female     No   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]>

# %%
  pd.isnull(df1).sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# dtype: int64

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time
# 0         16.99  1.01  Female     No   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female     No   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
df1["total_bill"]=df1['total_bill'].astype('int')

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df1['tip']=df1['tip'].astype('int')

# %%
df1
# Out:
#      total_bill  tip     sex smoker   day    time
# 0            16    1  Female     No   Sun  Dinner
# 1            10    1    Male     No   Sun  Dinner
# 2            21    3    Male     No   Sun  Dinner
# 3            23    3    Male     No   Sun  Dinner
# 4            24    3  Female     No   Sun  Dinner
# ..          ...  ...     ...    ...   ...     ...
# 239          29    5    Male     No   Sat  Dinner
# 240          27    2  Female    Yes   Sat  Dinner
# 241          22    2    Male    Yes   Sat  Dinner
# 242          17    1    Male     No   Sat  Dinner
# 243          18    3  Female     No  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time'], dtype='object')

# %%
df1.rename(columns={'sex':'Gender'},inplace=True)

# %%
df1.describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.319672    2.709016
# std      8.908096    1.417614
# min      3.000000    1.000000
# 25%     13.000000    2.000000
# 50%     17.000000    2.000000
# 75%     24.000000    3.000000
# max     50.000000   10.000000

# %%
df1[['total_bill','tip']].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.319672    2.709016
# std      8.908096    1.417614
# min      3.000000    1.000000
# 25%     13.000000    2.000000
# 50%     17.000000    2.000000
# 75%     24.000000    3.000000
# max     50.000000   10.000000

# %%
df1
# Out:
#      total_bill  tip     sex Smoker   day    time  size
# 0         16.99    1  Female     No   Sun  Dinner     2
# 1         10.34    1    Male     No   Sun  Dinner     3
# 2         21.01    3    Male     No   Sun  Dinner     3
# 3         23.68    3    Male     No   Sun  Dinner     2
# 4         24.59    3  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03    5    Male     No   Sat  Dinner     3
# 240       27.18    2  Female    Yes   Sat  Dinner     2
# 241       22.67    2    Male    Yes   Sat  Dinner     2
# 242       17.82    1    Male     No   Sat  Dinner     2
# 243       18.78    3  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.rename(columns={'smoker':'Smoker'},inplace=True)
df1
# Out:
#      total_bill  tip     sex Smoker   day    time  size
# 0         16.99    1  Female     No   Sun  Dinner     2
# 1         10.34    1    Male     No   Sun  Dinner     3
# 2         21.01    3    Male     No   Sun  Dinner     3
# 3         23.68    3    Male     No   Sun  Dinner     2
# 4         24.59    3  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03    5    Male     No   Sat  Dinner     3
# 240       27.18    2  Female    Yes   Sat  Dinner     2
# 241       22.67    2    Male    Yes   Sat  Dinner     2
# 242       17.82    1    Male     No   Sat  Dinner     2
# 243       18.78    3  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.rename(columns={'sex':'Gender'},inplace=True)
df1
# Out:
#      total_bill  tip  Gender Smoker   day    time  size
# 0         16.99    1  Female     No   Sun  Dinner     2
# 1         10.34    1    Male     No   Sun  Dinner     3
# 2         21.01    3    Male     No   Sun  Dinner     3
# 3         23.68    3    Male     No   Sun  Dinner     2
# 4         24.59    3  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03    5    Male     No   Sat  Dinner     3
# 240       27.18    2  Female    Yes   Sat  Dinner     2
# 241       22.67    2    Male    Yes   Sat  Dinner     2
# 242       17.82    1    Male     No   Sat  Dinner     2
# 243       18.78    3  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.709016    2.569672
# std      8.902412    1.417614    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.000000    2.000000
# 75%     24.127500    3.000000    3.000000
# max     50.810000   10.000000    6.000000

# %%
df1[['tip','size']].describe()
# Out:
#               tip        size
# count  244.000000  244.000000
# mean     2.709016    2.569672
# std      1.417614    0.951100
# min      1.000000    1.000000
# 25%      2.000000    2.000000
# 50%      2.000000    2.000000
# 75%      3.000000    3.000000
# max     10.000000    6.000000

# %%
df1['total_bill'].sum()
# Out:
# np.float64(4827.77)

# %%
df1['tip'].sum()
# Out:
# np.int64(661)

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'Gender', 'Smoker', 'day', 'time', 'size'], dtype='object')

# %%
##  Gender Wise Analysis  ##

# %% [markdown]
# ## Count PLot  ##

# %%
ax=sns.countplot(x='Gender',data=df1)

# %% [markdown]
# ## Scatter Plot  ##

# %%
sns.set_style('whitegrid')
ax=sns.scatterplot(data=df1,x='total_bill',y='tip',hue='Gender')

# %%
sns.set_context("poster")
ax=sns.scatterplot(data=df1,x='total_bill',y='tip',hue='Gender')
sns.despine()

# %%
ax=sns.scatterplot(data=df1,x='total_bill',y='tip',hue='Gender',palette='Set3')

# %%
ax=sns.scatterplot(data=df1,x='total_bill',y='tip',style='Gender',palette='Dark2',alpha=0.6)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9036\4111434445.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.scatterplot(data=df1,x='total_bill',y='tip',style='Gender',palette='Dark2',alpha=0.6)

# %%
ax=sns.scatterplot(data=df1,x='total_bill',y='tip',style='Gender',palette='Dark2',alpha=0.6)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9036\4111434445.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax=sns.scatterplot(data=df1,x='total_bill',y='tip',style='Gender',palette='Dark2',alpha=0.6)

# %% [markdown]
# ##  Stripplot  ##

# %%
sns.stripplot(data=df1,x='total_bill',y='tip',hue='Gender',dodge=True,jitter=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Swarm plot ##

# %%
sns.swarmplot(data=df1,x='Gender',y='tip')
# Out:
# <Axes: xlabel='Gender', ylabel='tip'>
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Hist Plot  ##

# %%
sns.histplot(data=df1,x='Smoker',y='tip')
# Out:
# <Axes: xlabel='Smoker', ylabel='tip'>

# %%
sns.histplot(data=df1,x='Gender',y='tip')
# Out:
# <Axes: xlabel='Gender', ylabel='tip'>

# %% [markdown]
# ## Regresion Plot ##

# %%
sns.regplot(data=df1,x='total_bill',y='tip',color='green')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##  Line plot ##

# %%
sns.set_style('whitegrid')
sns.lineplot(data=df1,x='total_bill',y='tip',hue='Gender',style="Smoker")
sns.set_context('poster')

# %% [markdown]
# ## Joint Plot ##

# %%
sns.jointplot(data=df1,x='Gender',y='tip')

# %%
sns.jointplot(data=df1,x='total_bill',y='tip',hue='Gender')

# %%
sns.jointplot(data=df1,x='total_bill',y='tip',hue='Gender',kind='kde')

# %% [markdown]
# ##  Bar Plot ##

# %%
sns.barplot(data=df1,x='tip',y='total_bill',hue='Gender',palette=['pink','skyblue'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
import statistics as sts

# %%
sns.barplot(data=df1,x='tip',y='total_bill',hue='Gender',palette=['pink','skyblue'],estimator=np.sum)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ## count plot

# %%
sns.countplot(data=df1,x='tip',hue='Gender',palette=['pink','skyblue'])
# Out:
# <Axes: xlabel='tip', ylabel='count'>

# %% [markdown]
# ##  Box Plot

# %%
sns.boxplot(data=df1,x='tip',y='total_bill',hue="Gender",palette=['pink','skyblue'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(data=df1,x='tip',y='total_bill',hue="Gender",split=True)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.violinplot(data=df1,x='tip',y='total_bill')
sns.swarmplot(data=df1,x='tip',y='total_bill',hue='Gender',size=3)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ## Kde Plot

# %%
sns.kdeplot(data=df1,x='tip',hue='Gender',palette='pastel',fill=True)
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.kdeplot(data=df1,x='tip',hue='Gender',fill=False)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# ## Heat map

# %%
columns=['total_bill','tip','size']
df1[columns].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.676296  0.598315
# tip           0.676296  1.000000  0.489712
# size          0.598315  0.489712  1.000000

# %%
sns.heatmap(data=df1[columns].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(data=df1[columns].corr(),annot=True,cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ## Rug Plot

# %%
sns.rugplot(data=df1,x='Gender',y='tip',palette='Set2')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_9036\2109112897.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.rugplot(data=df1,x='Gender',y='tip',palette='Set2')
# <Axes: xlabel='Gender', ylabel='tip'>

# %% [markdown]
# ## Pair Plot ##

# %%
sns.pairplot(data=df1,hue='Gender',palette='Set2')
