# %% [markdown]
# ## 1 Question

# %%
l1=["Sanskar","Salman","Rahul","Keshav","Zohan","Sakshi","Ayushi","Prateek"]
l1.append("Amir")
print(l1)
# Out:
# ['Sanskar', 'Salman', 'Rahul', 'Keshav', 'Zohan', 'Sakshi', 'Ayushi', 'Prateek', 'Amir']

# %%
l1[1]
# Out:
# 'Sanskar'

# %%
l1[-1]
# Out:
# 'Ayushi'

# %%
l1[-5:]
# Out:
# ['Sammi', 'Salman', 'Rahul', 'Prateek', 'Ayushi']

# %%
l1=["Sanskar","Salman","Rahul","Keshav","Zohan","Sakshi","Ayushi","Prateek"]
l1.insert(2,"Salmamm")
l1
# Out:
# ['Sanskar',
#  'Salman',
#  'Salmamm',
#  'Rahul',
#  'Keshav',
#  'Zohan',
#  'Sakshi',
#  'Ayushi',
#  'Prateek']

# %%
len(l1)
# Out:
# 7

# %%
l1
# Out:
# ['Sanskar', 'Salman', 'Rahul', 'Prateek']

# %%
l1=["Sanskar","Salman","Rahul","Keshav","Zohan","Sakshi","Ayushi","Prateek"]
l1.remove("Rahul")
l1
# Out:
# ['Sanskar', 'Salman', 'Keshav', 'Zohan', 'Sakshi', 'Ayushi', 'Prateek']

# %%
l1=["Sanskar","Salman","Rahul","Keshav","Zohan","Sakshi","Ayushi","Prateek"]
l1.pop()
l1
# Out:
# ['Sanskar', 'Salman', 'Rahul', 'Keshav', 'Zohan', 'Sakshi', 'Ayushi']

# %%
l1=["Sanskar","Salman","Rahul","Keshav","Zohan","Sakshi","Ayushi","Prateek"]
l1.pop(3)
l1
# Out:
# ['Sanskar', 'Salman', 'Rahul', 'Zohan', 'Sakshi', 'Ayushi', 'Prateek']

# %%
l1
# Out:
# ['Sanskar', 'Salman', 'Rahul', 'Zohan', 'Sakshi', 'Ayushi', 'Prateek']

# %%
l1[4]="Sammi"
l1
# Out:
# ['Sanskar', 'Salman', 'Rahul', 'Zohan', 'Sammi', 'Ayushi', 'Prateek']

# %%
x=[2,5,4,56,8]
y=["a","b","c","d"]
n=x+y
n
# Out:
# [2, 5, 4, 56, 8, 'a', 'b', 'c', 'd']

# %%
a=n*3
print(a)
# Out:
# [2, 5, 4, 56, 8, 'a', 'b', 'c', 'd', 2, 5, 4, 56, 8, 'a', 'b', 'c', 'd', 2, 5, 4, 56, 8, 'a', 'b', 'c', 'd']

# %%
l1.sort()
l1
# Out:
# ['Ayushi', 'Prateek', 'Rahul', 'Salman', 'Sammi', 'Sanskar', 'Zohan']

# %%
a=[6,6,56,5,5,66,5,6,6,6,6,5,5,95,5,4,6,5,46,46,54,54,4]
a.count(5)
# Out:
# 7

# %% [markdown]
# # 2 Question

# %% [markdown]
# ## Without Using Variable

# %%
a=[2, 5, 4, 56, 8, 'a', 'b', 'c', 'd']
a.reverse()
a
# Out:
# ['d', 'c', 'b', 'a', 8, 56, 4, 5, 2]

# %%
a=[2, 5, 4, 56]
a.sort()
a
# Out:
# [2, 4, 5, 56]

# %%
a.reverse()
a
# Out:
# [56, 5, 4, 2]

# %% [markdown]
# ## Using a Variable

# %%
s=[20,30,40,50]
x=s[1]
s[1]=s[3]
s[3]=x
print(s)
# Out:
# [20, 50, 40, 30]

# %% [markdown]
# ##  3 Dictonary Questions

# %%
a={"Name":"Raj","Age":20,"Course":"Data Scence"}
print(a)
# Out:
# {'Name': 'Raj', 'Age': 20, 'Course': 'Data Scence'}

# %%
type(a)
# Out:
# dict

# %%
a["Name"]
# Out:
# 'Raj'

# %%
a["Age"]
# Out:
# 20

# %%
a.get("Course")
# Out:
# 'Data Scence'

# %%
a["Grade"]="A"
a
# Out:
# {'Name': 'Raj', 'Age': 20, 'Course': 'Data Scence', 'Grade': 'A'}

# %%
a["Age"]=23
a
# Out:
# {'Name': 'Raj', 'Age': 23, 'Course': 'Data Scence', 'Grade': 'A'}

# %%
a={"Name":"Raj","Age":20,"Course":"Data Scence"}
a
# Out:
# {'Name': 'Raj', 'Age': 20, 'Course': 'Data Scence'}

# %%
del a["Age"]
a
# Out:
# {'Name': 'Raj', 'Course': 'Data Scence'}

# %%
a.pop("Course")
a
# Out:
# {'Name': 'Raj'}

# %%
a.clear()
a
# Out:
# {}

# %%
x={'Name': 'Raj', 'Age': 23, 'Course': 'Data Scence', 'Grade': 'A'}
len(x)
# Out:
# 4
