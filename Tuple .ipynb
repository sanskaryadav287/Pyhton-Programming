# %% [markdown]
# ##  Tuple All Methods  ##

# %%
##  Accessig Element  ##
x=("Ram","Sita", "Hanuman","Lakshman","Bharat","Satrughan")
x[0]
x[1]
x[-4]
x[1:]
x[-4:]
x[-3:5]
# Out:
# ('Lakshman', 'Bharat')

# %%
###  Add two Tuples  ##
x=(1,2,3)
y=(5,6,7)
x,y
print(x+y)
# Out:
# (1, 2, 3, 5, 6, 7)

# %%
##  Count  any digit or word in Tuple ##
z=(1, 2, 3, 5, 6, 7)
z.count(2)
# Out:
# 1

# %%
##   Find the endexing of Any Element  ##
x=("Ram","Sita", "Hanuman","Lakshman","Bharat","Satrughan")
x.index("Hanuman")
# Out:
# 2

# %%
len(x)
# Out:
# 6

# %%
##  Max Formula "
x=("Ram","Sita", "Hanuman","Lakshman","Bharat","Satrughan")
max(x)
z=(1, 2, 3, 5, 6, 7)
max(z)
# Out:
# 7

# %%
##  Min Formula   ##
x=("Ram","Sita", "Hanuman","Lakshman","Bharat","Satrughan")
min(x)
z=(1, 2, 3, 5, 6, 7)
min(z)
# Out:
# 1

# %%
##   Sum Formula   ##
z=(1, 2, 3, 5, 6, 7)
sum(z)
# Out:
# 24

# %%
z=(4,3,5,6,3,2,5,7,7,9,6,5,3,3,5,6,6,5,4,3,3,5,7,7,4,3,4,5,6,6, 5, 6, 7)
3in z
# Out:
# <>:2: SyntaxWarning: invalid decimal literal
# <>:2: SyntaxWarning: invalid decimal literal
# C:\Users\hp\AppData\Local\Temp\ipykernel_3076\1367910120.py:2: SyntaxWarning: invalid decimal literal
#   3in z
# True

# %%
## Nested Tuple  ##
t = (10, (20, 30), 40)
print(t[1][1])
# Out:
# 30

# %%
## Tuple In Tuple  ##
x=(1,2,3,(5,4,3),2,5)
x
# Out:
# (1, 2, 3, (5, 4, 3), 2, 5)
