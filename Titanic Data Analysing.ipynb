# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.shape)
print(df.dtypes)
df.info()
# Out:
# (891, 12)
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
df['IsAlone'] = (df['FamilySize'] == 1).astype(int)

# %%
df[df['Age'] > 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    0  54.0      0
# 11                            Bonnell, Miss. Elizabeth    1  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)     1  55.0      0
# 33                               Wheadon, Mr. Edward H    0  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    0  65.0      0
# ..                                                 ...  ...   ...    ...
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...    1  52.0      1
# 829          Stone, Mrs. George Nelson (Martha Evelyn)    1  62.0      0
# 851                                Svensson, Mr. Johan    0  74.0      0
# 857                             Daly, Mr. Peter Denis     0  51.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)    1  56.0      0
#
#      Parch      Ticket     Fare  Embarked  FamilySize  IsAlone
# 6        0       17463  51.8625         0           1        1
# 11       0      113783  26.5500         0           1        1
# 15       0      248706  16.0000         0           1        1
# 33       0  C.A. 24579  10.5000         0           1        1
# 54       1      113509  61.9792         1           2        0
# ..     ...         ...      ...       ...         ...      ...
# 820      1       12749  93.5000         0           3        0
# 829      0      113572  80.0000         0           1        1
# 851      0      347060   7.7750         0           1        1
# 857      0      113055  26.5500         0           1        1
# 879      1       11767  83.1583         1           2        0
#
# [64 rows x 13 columns]

# %%
df[df['Sex'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.000000      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
# ..                                                 ...  ...        ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)    1  25.000000      0
# 882                       Dahlberg, Miss. Gerda Ulrika    1  22.000000      0
# 885               Rice, Mrs. William (Margaret Norton)    1  39.000000      0
# 887                       Graham, Miss. Margaret Edith    1  19.000000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1  29.699118      1
#
#      Parch            Ticket     Fare  Embarked  FamilySize  IsAlone
# 1        0          PC 17599  71.2833         1           2        0
# 2        0  STON/O2. 3101282   7.9250         0           1        1
# 3        0            113803  53.1000         0           2        0
# 8        2            347742  11.1333         0           3        0
# 9        0            237736  30.0708         1           2        0
# ..     ...               ...      ...       ...         ...      ...
# 880      1            230433  26.0000         0           2        0
# 882      0              7552  10.5167         0           1        1
# 885      5            382652  29.1250         2           6        0
# 887      0            112053  30.0000         0           1        1
# 888      2        W./C. 6607  23.4500         0           4        0
#
# [314 rows x 13 columns]

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# 0    0.188908
# 1    0.742038
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    37.048118
# 2    29.866958
# 3    26.403259
# Name: Age, dtype: float64

# %%
df['Embarked'].value_counts().plot(kind='bar')
plt.title( Count")
plt.show()
# Out:
#   Cell In[2], line 2
#     plt.title( Count")
#                     ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.show()

# %%
df['Pclass'].value_counts().plot(kind='bar')
plt.title("Class Distribution")
plt.show()

# %%
df.to_csv("Titanic-Cleaned.csv", index=False)
