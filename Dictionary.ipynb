# %% [markdown]
#  ## Distionaery

# %%
CAR={"brand":"BMW","Model":"IX","Year":2000}
CAR
# Out:
# {'brand': 'BMW', 'Model': 'IX', 'Year': 2000}

# %%
print(CAR["brand"])
# Out:
# BMW

# %%
CAR["Model"]
# Out:
# 'IX'

# %%
CAR["Year"]
# Out:
# 2000

# %%
car={"brand":"BMW","Model":"IX","Year":2000,"Year":2013}
car
# Out:
# {'brand': 'BMW', 'Model': 'IX', 'Year': 2013}

# %%
len(car)
# Out:
# 3

# %%
type(car)
# Out:
# dict

# %%
print(type(car))
# Out:
# <class 'dict'>

# %%
car.keys()
# Out:
# dict_keys(['brand', 'Model', 'Year'])

# %%
car.values()
# Out:
# dict_values(['BMW', 'IX', 2013])

# %%
car["Year"]=2025
car
# Out:
# {'brand': 'BMW', 'Model': 'IX', 'Year': 2025}

# %%
car["Colour"]="White"
car
# Out:
# {'brand': 'BMW', 'Model': 'IX', 'Year': 2025, 'Colour': 'White'}

# %%
d1={"Name":"AA","Year":2004,"Pass":"True","Marks":[20,12,14,20]}
d1
# Out:
# {'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
d1.update({"Name":"Sanskar"})
d1
# Out:
# {'Name': 'Sanskar', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
d1["Phone"]="5448985"
d1
# Out:
# {'Name': 'Sanskar',
#  'Year': 2004,
#  'Pass': 'True',
#  'Marks': [20, 12, 14, 20],
#  'Phone': '5448985'}

# %%
d1.pop("Phone")
d1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 d1.pop("Phone")
#       2 d1
#
# KeyError: 'Phone'

# %%
d1.popitem()
d1
# Out:
# {'Name': 'Sanskar', 'Year': 2004}

# %%
 d3={"Name":"AA","Year":2004,"Pass":"True","Marks":[20,12,14,20]}
d3
# Out:
# {'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
del d3["Marks"]
d3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del d3["Marks"]
#       2 d3
#
# KeyError: 'Marks'

# %%
del d3()
d3
# Out:
#   Cell In[10], line 1
#     del d3()
#         ^
# SyntaxError: cannot delete function call

# %%
 d4={"Name":"AA","Year":2004,"Pass":"True","Marks":[20,12,14,20]}
d4
# Out:
# {'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
del d4()
d4
# Out:
#   Cell In[14], line 1
#     del d4()
#         ^
# SyntaxError: cannot delete function call

# %%
dd={"Name":"AA","Year":2004,"Pass":"True","Marks":[20,12,14,20]}
dd
# Out:
# {'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
de=dd.copy()
de
# Out:
# {'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
da=de.copy()
da
# Out:
# {'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}

# %%
x=list(da)
x
# Out:
# ['Name', 'Year', 'Pass', 'Marks']

# %%
y=str(da)
y
# Out:
# "{'Name': 'AA', 'Year': 2004, 'Pass': 'True', 'Marks': [20, 12, 14, 20]}"

# %%
q=dict(y)
q
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 q=dict(y)
#       2 q
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %% [markdown]
# ## Nested dicrt

# %%
myfaimly={"child1":{"Name":"Akku","Age":"20"},
        "child2":{"Name":"Ramu","Age":"25"}
}
myfaimly
# Out:
# {'child1': {'Name': 'Akku', 'Age': '20'},
#  'child2': {'Name': 'Ramu', 'Age': '25'}}

# %%
print(myfaimly["child1"]["Age"])
# Out:
# 20

# %%
myfaimly["child2"]
# Out:
# {'Name': 'Ramu', 'Age': '25'}

# %%
myfaimly["Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myfaimly["Name"]
#
# KeyError: 'Name'
